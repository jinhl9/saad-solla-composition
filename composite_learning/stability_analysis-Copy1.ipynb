# %%
import os
import argparse
from typing import List
from datetime import datetime
from dataclasses import dataclass
import data
import network
import solver
import joblib
import json
import torch

import matplotlib.pyplot as plt
import numpy as np
import time

# %%
def gram_schmidt(N, K):
    """
    Given the dimension space dimension N, generate K random vectors and its orthogonal spans
    """
    
    def proj(u,v):
        """
        Return projection of v to u
        """
        return np.dot(v,u)/np.dot(u,u) * u
    
    V=np.random.normal(loc = 0., scale = 1, size = (K, N))
    U=np.zeros_like(V)
    
    ## Initialise u1 to v1
    U[0] = V[0]
    
    ## Gram-schomidt process
    for k in range(1,K):
        projection_terms = [proj(U[i], V[k]) for i in range(k)]
        U[k] = V[k] - np.sum(projection_terms, axis=0)
    
    return V, U
        

def control_VS(VT, angle):
    dim = len(VT)
    VT_norm = VT/np.linalg.norm(VT)
    c = np.cos(angle)
    a = np.random.normal(loc = 0., scale = 1, size = (dim))
    b = np.random.normal(loc = 0., scale = 1, size = (dim))
    h = (b-a) - np.dot((b-a),VT_norm)*VT_norm
    v = np.cos(angle)*VT_norm + np.sin(angle)*h/np.linalg.norm(h)
    
    return v

# %%
num_task = 4
seq_len = 4
input_dim = 1000
nums_iter = np.array([100000,100000 ])
nums_iter_base = np.array([0,400000 ])
update_frequency = 1000

# %%
results_sim_curr_task = []

lr_v = 1
lr_wc = 1
for num_task in [4]:
    vt = np.ones(num_task)
    VT_i= np.array(vt)
    VT_i *= np.sqrt(num_task)/np.linalg.norm(VT_i)
    VT_ode=VT_i.copy()
    VS_i = control_VS(VT_i, np.pi/4) * np.sqrt(num_task)
    VS_ode = VS_i.copy()
    WT_i = np.random.normal(0, .1, (num_task,input_dim))
    #_, WT_i =gram_schmidt(input_dim, num_task)
    WT_ode = WT_i.copy()
    WS_i = WT_i.copy()
    c=0
    for w in WS_i:
        c+=1
        wt = control_VS(w, np.pi/3) * np.sqrt(input_dim)
        WS_i[c-1] =wt
    WS_ode = WS_i.copy()
    """
    WS_i = np.random.normal(0, .1, (num_task,input_dim))
    WS_i = np.divide(WS_i * np.sqrt(input_dim),
                        np.linalg.norm(WS_i, axis=1)[:, None])
    WS_ode = WS_i.copy()
    
    ode_solver_nid= solver.HRLODESolver(N = input_dim, seq_length = seq_len,
                                                                 VS = VS_ode, VT= VT_ode, WS=WS_ode, WT = WT_ode,
                                   lr_ws = [1., lr_wc], lr_v = lr_v, V_norm=0)
    
    ode_solver_nid.train(nums_iter= nums_iter, update_frequency = update_frequency)
    results_ode_curr_task.append(ode_solver_nid)
    """
    solver_nid = solver.CurriculumCompositionalTaskSimulator(input_dim = input_dim, seq_len = seq_len,
                                                                         num_task= num_task, identical = True,
                                                                         VS = VS_i, VT= VT_i, WS=WS_i, WT = WT_i, V_norm=1)
    solver_nid.train(lr = {'lr_w':1., 'lr_wc':lr_wc, 'lr_vc': lr_v},num_iter= nums_iter, update_frequency = update_frequency)

    results_sim_curr_task.append(solver_nid)
"""
solver_nid.setup_train()
solver_nid.setup_history(it)
ode_solver_nid.update_frequency=1
ode_solver_nid._setup_history([0,it])
ode_solver_nid._init_params()
DRS=[]
for i in range(it):
    sim_VS_pre = solver_nid.VS
    sim_Q_pre = solver_nid.WS@solver_nid.WS.T/solver_nid.input_dim
    sim_R_pre = solver_nid.WS@solver_nid.WT.T/solver_nid.input_dim
    solver_nid.step()
    solver_nid.update_history(i)
    sim_VS_post = solver_nid.VS

    sim_Q_post = solver_nid.WS@solver_nid.WS.T/solver_nid.input_dim
    sim_R_post = solver_nid.WS@solver_nid.WT.T/solver_nid.input_dim
    
    DV = solver_nid.dv
    DR = sim_R_post -sim_R_pre
    ode_solver_nid.train_iter = i
    ode_solver_nid._step2(True, DV=DV, DQ=None, DR=None)
    #if np.all(DR) !=0:
    DRS.append(DR)
"""
# Out:
# '\nsolver_nid.setup_train()\nsolver_nid.setup_history(it)\node_solver_nid.update_frequency=1\node_solver_nid._setup_history([0,it])\node_solver_nid._init_params()\nDRS=[]\nfor i in range(it):\n    sim_VS_pre = solver_nid.VS\n    sim_Q_pre = solver_nid.WS@solver_nid.WS.T/solver_nid.input_dim\n    sim_R_pre = solver_nid.WS@solver_nid.WT.T/solver_nid.input_dim\n    solver_nid.step()\n    solver_nid.update_history(i)\n    sim_VS_post = solver_nid.VS\n\n    sim_Q_post = solver_nid.WS@solver_nid.WS.T/solver_nid.input_dim\n    sim_R_post = solver_nid.WS@solver_nid.WT.T/solver_nid.input_dim\n    \n    DV = solver_nid.dv\n    DR = sim_R_post -sim_R_pre\n    ode_solver_nid.train_iter = i\n    ode_solver_nid._step2(True, DV=DV, DQ=None, DR=None)\n    #if np.all(DR) !=0:\n    DRS.append(DR)\n'

# %%
results_sim_base_task = []

lr_v = 1
lr_wc = 1
for num_task in [4]:
    vt = np.ones(num_task)
    VT_i= np.array(vt)
    VT_i *= np.sqrt(num_task)/np.linalg.norm(VT_i)
    VT_ode=VT_i.copy()
    VS_i = control_VS(VT_i, np.pi/4) * np.sqrt(num_task)
    VS_ode = VS_i.copy()
    WT_i = np.random.normal(0, .1, (num_task,input_dim))
    WT_ode = WT_i.copy()
    WS_i = WT_i.copy()
    c=0
    for w in WS_i:
        c+=1
        wt = control_VS(w, np.pi/3) * np.sqrt(input_dim)
        WS_i[c-1] =wt
    WS_ode = WS_i.copy()
    """
    WS_i = np.random.normal(0, .1, (num_task,input_dim))
    WS_i = np.divide(WS_i * np.sqrt(input_dim),
                        np.linalg.norm(WS_i, axis=1)[:, None])
    WS_ode = WS_i.copy()
    
    ode_solver_nid= solver.HRLODESolver(N = input_dim, seq_length = seq_len,
                                                                 VS = VS_ode, VT= VT_ode, WS=WS_ode, WT = WT_ode,
                                   lr_ws = [1., lr_wc], lr_v = lr_v, V_norm=0)
    
    ode_solver_nid.train(nums_iter= nums_iter, update_frequency = update_frequency)
    results_ode_curr_task.append(ode_solver_nid)
    """
    solver_nid = solver.CurriculumCompositionalTaskSimulator(input_dim = input_dim, seq_len = seq_len,
                                                                         num_task= num_task, identical = True,
                                                                         VS = VS_i, VT= VT_i, WS=WS_i, WT = WT_i, V_norm=1)
    solver_nid.train(lr = {'lr_w':1., 'lr_wc':lr_wc, 'lr_vc': lr_v},num_iter= nums_iter_base, update_frequency = update_frequency)

    results_sim_base_task.append(solver_nid)
"""
solver_nid.setup_train()
solver_nid.setup_history(it)
ode_solver_nid.update_frequency=1
ode_solver_nid._setup_history([0,it])
ode_solver_nid._init_params()
DRS=[]
for i in range(it):
    sim_VS_pre = solver_nid.VS
    sim_Q_pre = solver_nid.WS@solver_nid.WS.T/solver_nid.input_dim
    sim_R_pre = solver_nid.WS@solver_nid.WT.T/solver_nid.input_dim
    solver_nid.step()
    solver_nid.update_history(i)
    sim_VS_post = solver_nid.VS

    sim_Q_post = solver_nid.WS@solver_nid.WS.T/solver_nid.input_dim
    sim_R_post = solver_nid.WS@solver_nid.WT.T/solver_nid.input_dim
    
    DV = solver_nid.dv
    DR = sim_R_post -sim_R_pre
    ode_solver_nid.train_iter = i
    ode_solver_nid._step2(True, DV=DV, DQ=None, DR=None)
    #if np.all(DR) !=0:
    DRS.append(DR)
"""
# Out:
# '\nsolver_nid.setup_train()\nsolver_nid.setup_history(it)\node_solver_nid.update_frequency=1\node_solver_nid._setup_history([0,it])\node_solver_nid._init_params()\nDRS=[]\nfor i in range(it):\n    sim_VS_pre = solver_nid.VS\n    sim_Q_pre = solver_nid.WS@solver_nid.WS.T/solver_nid.input_dim\n    sim_R_pre = solver_nid.WS@solver_nid.WT.T/solver_nid.input_dim\n    solver_nid.step()\n    solver_nid.update_history(i)\n    sim_VS_post = solver_nid.VS\n\n    sim_Q_post = solver_nid.WS@solver_nid.WS.T/solver_nid.input_dim\n    sim_R_post = solver_nid.WS@solver_nid.WT.T/solver_nid.input_dim\n    \n    DV = solver_nid.dv\n    DR = sim_R_post -sim_R_pre\n    ode_solver_nid.train_iter = i\n    ode_solver_nid._step2(True, DV=DV, DQ=None, DR=None)\n    #if np.all(DR) !=0:\n    DRS.append(DR)\n'

# %%
ax1=plt.subplot(121)
ax1.plot(results_sim_curr_task[0].history['overlap'])
ax2=plt.subplot(122)
ax2.plot(results_sim_base_task[0].history['overlap'])
# Out:
# [<matplotlib.lines.Line2D at 0x7fdfa35cb8e0>,
#  <matplotlib.lines.Line2D at 0x7fdfa35cb940>,
#  <matplotlib.lines.Line2D at 0x7fdfa35cb970>,
#  <matplotlib.lines.Line2D at 0x7fdfa35cba60>]

# %%
ax1=plt.subplot(121)
ax1.plot(results_sim_curr_task[0].history['overlap_tilde'])
ax2=plt.subplot(122)
ax2.plot(results_sim_base_task[0].history['overlap_tilde'])

# %%
ax1=plt.subplot(121)
ax1.plot(results_sim_curr_task[0].history['VSVT'])
ax2=plt.subplot(122)
ax2.plot(results_sim_base_task[0].history['VSVT'])
# Out:
# [<matplotlib.lines.Line2D at 0x7fdfa339d930>,
#  <matplotlib.lines.Line2D at 0x7fdfa339d990>,
#  <matplotlib.lines.Line2D at 0x7fdfa339d9c0>,
#  <matplotlib.lines.Line2D at 0x7fdfa339dab0>]

# %%
nums=[4,8,16]
c=0
for i in range(1):
    for k in range(4):
        plt.plot(results_ode_base[i].history['phase1']['overlap'][:,k], c = 'k',
                 alpha = i* 0.2 + 0.2, ls = '--')
        post = plt.plot(np.arange(len(results_ode_base[i].history['phase1']['overlap']),
                               len(results_ode_base[i].history['phase1']['overlap'])+ len(results_ode_base[i].history['phase2']['overlap'])),
                     results_ode_base[i].history['phase2']['overlap'][:,k], c = 'k',
                 alpha = i* 0.2 + 0.2, label = f'prim.task {k}')
    
plt.xlabel('Time (x1000)')
plt.legend()

# %%
nums=[4,8,16]
for i in range(1):
    pre =plt.plot(np.arange(len(results_ode_curr_task[i].history['phase1']['overlap'])),
             results_ode_curr_task[i].history['phase1']['overlap'], c = 'k',
             alpha = i* 0.2 + 0.2,
            ls = '--')
    post = plt.plot(np.arange(len(results_ode_curr_task[i].history['phase1']['overlap']),
                           len(results_ode_curr_task[i].history['phase1']['overlap'])+ len(results_ode_curr_task[i].history['phase2']['overlap'])),
                 results_ode_curr_task[i].history['phase2']['overlap'], c = 'k',
             alpha = i* 0.2 + 0.2, label = nums[i])
plt.legend(title = ' # task (K)', )
plt.xlabel('Time (x1000)')
# Out:
# Text(0.5, 0, 'Time (x1000)')

# %%
nums=[4,8,16]
for i in range(3):
    pre =plt.plot(np.arange(len(results_ode_curr_len_norm[i].history['phase1']['overlap_tilde'])),
             results_ode_curr_len_norm[i].history['phase1']['overlap_tilde'], c = 'k',
             alpha = i* 0.2 + 0.2,
            ls = '--')
    post = plt.plot(np.arange(len(results_ode_curr_len_norm[i].history['phase1']['overlap_tilde']),
                           len(results_ode_curr_len_norm[i].history['phase1']['overlap_tilde'])+ len(results_ode_curr_len_norm[i].history['phase2']['overlap_tilde'])),
                 results_ode_curr_len_norm[i].history['phase2']['overlap_tilde'], c = 'k',
             alpha = i* 0.2 + 0.2, label = nums[i])
plt.legend(title = 'length (T)', )
plt.xlabel('Time (x1000)')
# Out:
# Text(0.5, 0, 'Time (x1000)')

# %%
nums=[4,8,16]
for i in range(3):
    pre =plt.plot(np.arange(len(results_ode_base_len_norm[i].history['phase1']['overlap_tilde'])),
             results_ode_base_len_norm[i].history['phase1']['overlap_tilde'], c = 'k',
             alpha = i* 0.2 + 0.2,
            ls = '--')
    post = plt.plot(np.arange(len(results_ode_base_len_norm[i].history['phase1']['overlap_tilde']),
                           len(results_ode_base_len_norm[i].history['phase1']['overlap_tilde'])+ len(results_ode_base_len_norm[i].history['phase2']['overlap_tilde'])),
                 results_ode_base_len_norm[i].history['phase2']['overlap_tilde'], c = 'k',
             alpha = i* 0.2 + 0.2, label = nums[i])
plt.legend(title = 'length (T)', )
plt.xlabel('Time (x1000)')
# Out:
# Text(0.5, 0, 'Time (x1000)')

# %%
nums=[2,4,8]
for i in range(1):
    post = plt.plot(results_ode_base_task[i].history['phase2']['P_tilde'], c = 'k',
             alpha = i* 0.2 + 0.2, label = nums[i])
plt.legend(title = '# task (K)', )
plt.xlabel('Time (x1000)')
# Out:
# Text(0.5, 0, 'Time (x1000)')

# %%
a=[]
b= []
for i in range(1000):
    x = np.random.normal(loc=0.0,
                     scale=1.0,
                     size=(num_task, input_dim,
                                       seq_len))
    (y, y_sign, y_hat,
         y_hat_sign), (y_tilde, y_tilde_hat, y_tilde_sign,
                       y_tilde_hat_sign) = solver_nid.inference(x)
    b.append(y_tilde_sign == y_tilde_hat_sign)

# %%
for i in range(3):
    plt.plot(results_ode[i].history['phase2']['P_tilde'], ls = '--')
    plt.plot(results_sim[i].history['P_tilde'])

# %%
for i in range(2):
    plt.plot(np.concatenate([results_ode_curr[i].history['phase1']['overlap'][:,0], results_ode_curr[i].history['phase2']['overlap'][:,0]]), ls = '--')
    plt.plot(results_sim_curr[i].history['overlap'][:,0])

# %%
for i in range(2):
    plt.plot(np.concatenate([results_ode_curr[i].history['phase1']['overlap_tilde'], 
                             results_ode_curr[i].history['phase2']['overlap_tilde']]), ls = '--')
    plt.plot(results_sim_curr[i].history['overlap_tilde'])

# %%
plt.plot(np.concatenate([ode_solver_nid.history['phase1']['P_tilde']
        ,ode_solver_nid.history['phase2']['P_tilde']]), ls= '--')
plt.plot(solver_nid.history['P_tilde'])

# %%
ode_solver_nid.history['phase2']['Q'][:,0,0]
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
np.linalg.norm(sim_R_post)
# Out:
# 1.3058188394206574

# %%
np.linalg.norm(sim_R_post)
# Out:
# 1.2966641038548354

# %%
DR
# Out:
# array([[-2.41368459e-04,  6.63557407e-04,  9.39364960e-05,
#          3.10719723e-04],
#        [-1.10000659e-04,  5.71243351e-04, -5.26536825e-04,
#          7.35365200e-04],
#        [-1.82078808e-04, -1.56042173e-04,  3.48539843e-04,
#          4.12251995e-04],
#        [-9.95957671e-04, -4.93559096e-04,  3.49904908e-04,
#         -5.58180264e-04]])

# %%
# Curriculum version
#for i,vt in enumerate([np.random.normal(0,1, (4)), np.random.normal(0,1, (4)), np.random.normal(0,1, (4)), np.random.normal(0,1, (4))]):
vt = [.1,.1,.1,.1,]
results = {}

for lr_v in [1]:
    results[lr_v]={}
    for lr_wc in [1]: 
        results[lr_v][lr_wc] = []
        for s in np.arange(1):
            VT_i= np.array(vt)
            VT_ode=VT_i.copy()
            VS_i =control_VS(VT_i, np.pi/4)
            VS_ode = VS_i.copy()
            _, WT_i =gram_schmidt(input_dim, num_task)
            WT_ode = WT_i.copy()
            WS_i = np.random.normal(0, .1, (num_task,input_dim))
            WS_i = np.divide(WS_i * np.sqrt(input_dim),
                                np.linalg.norm(WS_i, axis=1)[:, None])
            WS_ode = WS_i.copy()
            ode_solver_nid= solver.HRLODESolver(N = input_dim, seq_length = seq_len,
                                                                         VS = VS_ode, VT= VT_ode, WS=WS_ode, WT = WT_ode,
                                           lr_ws = [1., lr_wc], lr_v = lr_v )
            solver_nid = solver.CurriculumCompositionalTaskSimulator(input_dim = input_dim, seq_len = seq_len,
                                                                         num_task= num_task, identical = False,
                                                                         VS = VS_i, VT= VT_i, WS=WS_i, WT = WT_i)
            solver_nid.train(lr = {'lr_w':1., 'lr_wc':lr_wc, 'lr_vc': lr_v},num_iter= nums_iter, update_frequency = update_frequency)
            ode_solver_nid.train(nums_iter= nums_iter, update_frequency = update_frequency)
            results[lr_v][lr_wc].append(solver_nid)
# Out:
# /nfs/nhome/live/jlee/rotation_saxe/composite_learning/solver/simple_hrl_solver.py:490: RuntimeWarning: invalid value encountered in sqrt
#   dR = self.lr_w1 / self.N / sqrt2pi * (np.diag(np.sqrt(
# /nfs/nhome/live/jlee/rotation_saxe/composite_learning/solver/simple_hrl_solver.py:491: RuntimeWarning: invalid value encountered in sqrt
#   self.S)) + np.diag(self.R) / np.diag(np.sqrt(self.Q))) * np.power(
# /nfs/nhome/live/jlee/rotation_saxe/composite_learning/solver/simple_hrl_solver.py:494: RuntimeWarning: invalid value encountered in sqrt
#   self.Q)) + np.diag(self.R) / np.diag(np.sqrt(self.S))) * np.power(

# %%
ode_solver_nid.S
# Out:
# array([[ 1.00000000e+00, -1.77635684e-18,  0.00000000e+00,
#          3.55271368e-17],
#        [-1.77635684e-18,  1.00000000e+00,  7.10542736e-18,
#          5.32907052e-18],
#        [ 0.00000000e+00,  7.10542736e-18,  1.00000000e+00,
#          3.19744231e-17],
#        [ 3.55271368e-17,  5.32907052e-18,  3.19744231e-17,
#          1.00000000e+00]])

# %%
solver_nid.S
# Out:
# array([[ 1.00000000e+00, -1.77635684e-18,  0.00000000e+00,
#          3.55271368e-17],
#        [-1.77635684e-18,  1.00000000e+00,  7.10542736e-18,
#          5.32907052e-18],
#        [ 0.00000000e+00,  7.10542736e-18,  1.00000000e+00,
#          3.19744231e-17],
#        [ 3.55271368e-17,  5.32907052e-18,  3.19744231e-17,
#          1.00000000e+00]])

# %%
WT_ode = WT_i.copy()
WS_i = np.random.normal(0, .1, (num_task,input_dim))

# %%
np.linalg.norm(WS_i[0])
# Out:
# 31.622776601683796

# %%
WS_i = np.random.normal(0, .1, (num_task,input_dim))
WS_i = np.divide(WS_i * np.sqrt(input_dim),
                    np.linalg.norm(WS_i, axis=1)[:, None])

# %%
fig = plt.figure()
#for i in range(4):
    #plt.plot(ode_solver_nid.history['phase2']['R'][:,i,i]/np.sqrt(ode_solver_nid.history['phase2']['Q'][:,i,i])/np.sqrt(ode_solver_nid.S[i,i]))
plt.plot(ode_solver_nid.history['phase2']['P'])    
fig = plt.figure()
plt.plot(ode_solver_nid.history['phase2']['P_tilde'])

fig = plt.figure()
plt.plot(ode_solver_nid.history['phase2']['VS'])
fig = plt.figure()
for i in range(0,4):
    plt.plot(ode_solver_nid.history['phase2']['R'][:,i,i])
#a=[np.sqrt(np.sum(np.power(solver_nid.history['phase2']['VS'][i],2) * np.diag(solver_nid.history['phase2']['Q'][i])))/2 for i in range(200)]
#plt.plot(a)

# %%
np.sqrt(np.sum(solver_nid.VS*solver_nid.VS * np.diag(solver_nid.WS @ solver_nid.WS.T/1000)))
# Out:
# 1.0

# %%
(solver_nid.WS * solver_nid.WS).shape
# Out:
# (4, 1000)

# %%
solver_nid.R
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 solver_nid.R
#
# AttributeError: 'CurriculumCompositionalTaskSimulator' object has no attribute 'R'

# %%
np.linalg.norm(ode_solver_nid.history['phase2']['R'], axis=(1,2))
# Out:
# array([1.46633872e-01, 6.98805952e-01, 2.17892945e+00, 5.62752994e+00,
#        1.33934589e+01, 3.06539710e+01, 6.89855549e+01, 1.54102314e+02,
#        3.43103675e+02, 7.62778686e+02, 1.69466076e+03, 3.76389060e+03,
#        8.35858357e+03, 1.85610285e+04, 4.12154000e+04, 9.15190824e+04,
#        2.03217633e+05, 4.51242542e+05, 1.00197803e+06, 2.22487767e+06,
#        4.94030747e+06, 1.09698774e+07, 2.43584445e+07, 5.40875513e+07,
#        1.20100574e+08, 2.66681473e+08, 5.92162097e+08, 1.31488680e+09,
#        2.91968586e+09, 6.48311741e+09, 1.43956622e+10, 3.19653458e+10,
#        7.09785573e+10, 1.57606792e+11, 3.49963449e+11, 7.77088440e+11,
#        1.72551289e+12, 3.83147476e+12, 8.50773059e+12, 1.88912845e+13,
#        4.19478059e+13, 9.31444558e+13, 2.06825827e+14, 4.59253559e+14,
#        1.01976544e+15, 2.26437343e+15, 5.02800627e+15, 1.11646104e+16,
#        2.47908451e+16, 5.50476890e+16, 1.22232544e+17, 2.71415479e+17,
#        6.02673884e+17, 1.33822806e+18, 2.97151477e+18, 6.59820269e+18,
#        1.46512073e+19, 3.25327798e+19, 7.22385356e+19, 1.60404554e+20,
#        3.56175837e+20, 7.90882952e+20, 1.75614339e+21, 3.89948931e+21,
#        8.65875586e+21, 1.92266338e+22, 4.26924438e+22, 9.47979128e+22,
#        2.10497303e+23, 4.67406014e+23, 1.03786784e+24, 2.30456953e+24,
#        5.11726110e+24, 1.13627993e+25, 2.52309206e+25, 5.60248700e+25,
#        1.24402359e+26, 2.76233520e+26, 6.13372270e+26, 1.36198366e+27,
#        3.02426371e+27, 6.71533091e+27, 1.49112887e+28, 3.31102865e+28,
#        7.35208804e+28, 1.63251981e+29, 3.62498505e+29, 8.04922337e+29,
#        1.78731763e+30, 3.96871123e+30, 8.81246206e+30, 1.95679361e+31,
#        4.34503001e+31, 9.64807212e+31, 2.14233953e+32, 4.75703187e+32,
#        1.05629159e+33, 2.34547918e+33, 5.20810033e+33, 1.15645064e+34])

# %%
fig = plt.figure()
#for i in range(4):
    #plt.plot(ode_solver_nid.history['phase2']['R'][:,i,i]/np.sqrt(ode_solver_nid.history['phase2']['Q'][:,i,i])/np.sqrt(ode_solver_nid.S[i,i]))
plt.plot(solver_nid.history['P'])    
fig = plt.figure()
plt.plot(solver_nid.history['P_tilde'])

fig = plt.figure()
plt.plot(solver_nid.history['VS'])
fig = plt.figure()
for i in range(4):
    plt.plot(solver_nid.history['R'][:,i,i])

# %%
vt = [.2,.1,.1,.1,]
results = {}

for lr_v in [1]:
    results[lr_v]={}
    for lr_wc in [1]: 
        results[lr_v][lr_wc] = []
        for s in np.arange(1):
            VT_i= np.array(vt)
            VS_i =control_VS(VT_i, np.pi/4)
            _, WT_i =gram_schmidt(input_dim, num_task)
            WS_i = np.random.normal(0, .1, (num_task,input_dim))
            WS_i = np.divide(WS_i * np.sqrt(input_dim),
                                np.linalg.norm(WS_i, axis=1)[:, None])
            
            results[lr_v][lr_wc].append(ode_solver_nid)

# %%
fig = plt.figure()
#for i in range(4):
    #plt.plot(ode_solver_nid.history['phase2']['R'][:,i,i]/np.sqrt(ode_solver_nid.history['phase2']['Q'][:,i,i])/np.sqrt(ode_solver_nid.S[i,i]))
plt.plot(ode_solver_nid.history['P'])    
fig = plt.figure()
plt.plot(ode_solver_nid.history['P_tilde'])

fig = plt.figure()
plt.plot(ode_solver_nid.history['VS'])
fig = plt.figure()
ode_solver_nid.history['R'][:,1,1]
# Out:
# array([-0.00211202,  0.11296742,  0.23191643,  0.35408583,  0.51533188,
#         0.66566714,  0.76292673,  0.83521742,  0.86131511,  0.87099435,
#         0.87593531,  0.87551494,  0.87685714,  0.8764117 ,  0.87705186,
#         0.87760296,  0.87381437,  0.87266941,  0.876178  ,  0.87648359,
#         0.87916853,  0.88166901,  0.87758923,  0.87998535,  0.87859927,
#         0.87110692,  0.87095087,  0.87359113,  0.8787198 ,  0.8831547 ,
#         0.88296709,  0.88070618,  0.8804261 ,  0.8727407 ,  0.87639384,
#         0.87975262,  0.87733311,  0.87206273,  0.88367713,  0.87081846,
#         0.87582862,  0.8760367 ,  0.88386798,  0.88153639,  0.87642541,
#         0.87842276,  0.87732763,  0.87176249,  0.87724304,  0.88341629,
#         0.87629253,  0.8778547 ,  0.87874534,  0.88532943,  0.87859864,
#         0.86767108,  0.87068523,  0.8806182 ,  0.8727193 ,  0.87265364,
#         0.86590616,  0.87194826,  0.87199589,  0.87364416,  0.86811751,
#         0.8739059 ,  0.88604757,  0.88279163,  0.86807627,  0.8708104 ,
#         0.86653414,  0.87104915,  0.87650413,  0.87737347,  0.87361487,
#         0.88269608,  0.88182071,  0.87512178,  0.87905271,  0.87892899,
#         0.88294371,  0.87510136,  0.87807811,  0.89035396,  0.87877352,
#         0.87732974,  0.88324222,  0.8768506 ,  0.87956761,  0.88174675,
#         0.8757624 ,  0.87691735,  0.88070048,  0.87802846,  0.87644167,
#         0.88365461,  0.88061541,  0.87907115,  0.8740646 ,  0.86948669,
#         0.87918805,  0.87547879,  0.87353849,  0.86944356,  0.86497113,
#         0.86388878,  0.85924011,  0.86080487,  0.85786735,  0.85900236,
#         0.8592514 ,  0.8596739 ,  0.86016698,  0.85965957,  0.86052305,
#         0.86208037,  0.86216087,  0.86424898,  0.8648148 ,  0.86681571,
#         0.86614885,  0.86766563,  0.86930236,  0.87125657,  0.87268587,
#         0.8733255 ,  0.87415039,  0.87495684,  0.87661423,  0.87680061,
#         0.87899909,  0.87914909,  0.87945696,  0.878159  ,  0.87868245,
#         0.87861419,  0.87665435,  0.87760706,  0.87745023,  0.87580886,
#         0.87587004,  0.87736684,  0.87698196,  0.87897455,  0.8779825 ,
#         0.87812881,  0.87689942,  0.87430958,  0.8730357 ,  0.87253945,
#         0.87317649,  0.87179125,  0.87118846,  0.8705597 ,  0.87341932,
#         0.87494866,  0.87623624,  0.87589321,  0.87660581,  0.87737619,
#         0.87499861,  0.8718137 ,  0.87235582,  0.87039549,  0.86937596,
#         0.86797946,  0.86367442,  0.86247345,  0.86024247,  0.86068546,
#         0.86370745,  0.86387572,  0.86462966,  0.86481303,  0.86721161,
#         0.86856163,  0.87234761,  0.87174798,  0.87302076,  0.87087007,
#         0.87014334,  0.87117838,  0.86920576,  0.86957207,  0.86971486,
#         0.87258413,  0.87307825,  0.87278025,  0.87254017,  0.87429757,
#         0.87458952,  0.87616814,  0.8758484 ,  0.87625844,  0.8754687 ,
#         0.87480463,  0.87508761,  0.87543827,  0.87578174,  0.87560541])

# %%
ode_solver_nid.history['R'][:,i,i]/np.sqrt(ode_solver_nid.history['Q'][:,i,i])
# Out:
# array([ 0.0279011 ,  0.11933577,  0.02691336,  0.08843294,  0.05939571,
#         0.04938842,  0.03903628,  0.05783513,  0.07194361,  0.05127532,
#         0.02301105,  0.05140271,  0.02845182,  0.01923199,  0.05287578,
#         0.08995747,  0.09612248,  0.09925756,  0.07184931,  0.10725279,
#         0.03776533,  0.04223077,  0.04128054,  0.05514653,  0.05267604,
#         0.07577025,  0.01262868,  0.06689158,  0.07596873,  0.07168994,
#         0.08152151,  0.01816984,  0.11260629,  0.09901513,  0.05798162,
#         0.02508361,  0.08376456,  0.06096185, -0.01736809,  0.07632761,
#         0.1059797 ,  0.02929846,  0.07747453,  0.05918504,  0.09626322,
#         0.02867348,  0.08606079,  0.07824953,  0.05672734,  0.07096075,
#         0.04170148, -0.0093013 ,  0.06648743,  0.04866719,  0.0721839 ,
#         0.03448516,  0.08040384,  0.05378373,  0.04181972,  0.07969451,
#         0.01618539,  0.03689602,  0.02515944,  0.06751744,  0.06396241,
#         0.07227556,  0.05540428,  0.02685361,  0.06231177,  0.08599745,
#         0.03184061,  0.04068727,  0.10249608,  0.10554733,  0.00584265,
#         0.07666526,  0.02769694,  0.04499701,  0.05635046,  0.05109853,
#         0.09340053,  0.0230756 ,  0.04891468,  0.09443125,  0.01673916,
#         0.046969  ,  0.04221955,  0.04273588,  0.05568813,  0.03715082,
#        -0.01352844,  0.01216605,  0.05912821,  0.04451909,  0.09393611,
#         0.08604294,  0.07118079,  0.0794183 ,  0.03650112,  0.06683746])

# %%
np.diag(np.ones((400,4,4)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 np.diag(np.ones((400,4,4)))
#
# File <__array_function__ internals>:200, in diag(*args, **kwargs)
#
# File ~/.conda/envs/composite_learning/lib/python3.10/site-packages/numpy/lib/twodim_base.py:309, in diag(v, k)
#     307     return diagonal(v, k)
#     308 else:
# --> 309     raise ValueError("Input must be 1- or 2-d.")
#
# ValueError: Input must be 1- or 2-d.

# %%
solver_nid.history['phase2']['VS'][:,0]
# Out:
# array([0.94890005, 0.98866111, 0.99939675, 0.99989097, 0.99994068,
#        0.99996051, 0.99997152, 0.99997837, 0.99998295, 0.99998618,
#        0.99998856, 0.99999035, 0.99999174, 0.99999285, 0.99999374,
#        0.99999447, 0.99999508, 0.99999559, 0.99999602, 0.99999639,
#        0.99999671, 0.99999699, 0.99999723, 0.99999745, 0.99999764,
#        0.99999781, 0.99999796, 0.99999809, 0.99999822, 0.99999833,
#        0.99999843, 0.99999852, 0.9999986 , 0.99999868, 0.99999875,
#        0.99999881, 0.99999887, 0.99999893, 0.99999898, 0.99999902,
#        0.99999907, 0.99999911, 0.99999915, 0.99999918, 0.99999922,
#        0.99999925, 0.99999928, 0.99999931, 0.99999933, 0.99999936,
#        0.99999938, 0.9999994 , 0.99999942, 0.99999944, 0.99999946,
#        0.99999948, 0.9999995 , 0.99999951, 0.99999953, 0.99999954,
#        0.99999956, 0.99999957, 0.99999958, 0.99999959, 0.99999961,
#        0.99999962, 0.99999963, 0.99999964, 0.99999965, 0.99999966,
#        0.99999966, 0.99999967, 0.99999968, 0.99999969, 0.9999997 ,
#        0.9999997 , 0.99999971, 0.99999972, 0.99999972, 0.99999973,
#        0.99999974, 0.99999974, 0.99999975, 0.99999975, 0.99999976,
#        0.99999976, 0.99999977, 0.99999977, 0.99999978, 0.99999978,
#        0.99999979, 0.99999979, 0.9999998 , 0.9999998 , 0.9999998 ,
#        0.99999981, 0.99999981, 0.99999982, 0.99999982, 0.99999982,
#        0.99999983, 0.99999983, 0.99999983, 0.99999983, 0.99999984,
#        0.99999984, 0.99999984, 0.99999985, 0.99999985, 0.99999985,
#        0.99999985, 0.99999986, 0.99999986, 0.99999986, 0.99999986,
#        0.99999986, 0.99999987, 0.99999987, 0.99999987, 0.99999987,
#        0.99999987, 0.99999988, 0.99999988, 0.99999988, 0.99999988,
#        0.99999988, 0.99999989, 0.99999989, 0.99999989, 0.99999989,
#        0.99999989, 0.99999989, 0.99999989, 0.9999999 , 0.9999999 ,
#        0.9999999 , 0.9999999 , 0.9999999 , 0.9999999 , 0.9999999 ,
#        0.99999991, 0.99999991, 0.99999991, 0.99999991, 0.99999991,
#        0.99999991, 0.99999991, 0.99999991, 0.99999991, 0.99999992,
#        0.99999992, 0.99999992, 0.99999992, 0.99999992, 0.99999992,
#        0.99999992, 0.99999992, 0.99999992, 0.99999992, 0.99999992,
#        0.99999993, 0.99999993, 0.99999993, 0.99999993, 0.99999993,
#        0.99999993, 0.99999993, 0.99999993, 0.99999993, 0.99999993,
#        0.99999993, 0.99999993, 0.99999993, 0.99999994, 0.99999994,
#        0.99999994, 0.99999994, 0.99999994, 0.99999994, 0.99999994,
#        0.99999994, 0.99999994, 0.99999994, 0.99999994, 0.99999994,
#        0.99999994, 0.99999994, 0.99999994, 0.99999994, 0.99999995,
#        0.99999995, 0.99999995, 0.99999995, 0.99999995, 0.99999995,
#        0.99999995, 0.99999995, 0.99999995, 0.99999995, 0.99999995])

# %%
solver_nid.history['VS'].shape
# Out:
# (100, 4)

# %%
a=[]
b= []
num_task = 2
for i in range(1000):
    x = np.random.normal(loc=0.0,
                     scale=1.0,
                     size=(num_task, input_dim,
                                       seq_len))
    (y, y_sign, y_hat,
         y_hat_sign), (y_tilde, y_tilde_hat, y_tilde_sign,
                       y_tilde_hat_sign) = results_sim_curr_task[0].inference(x)
    b.append(y_sign == y_hat_sign)

# %%
np.mean(b)
# Out:
# 0.711

# %%
#Baseline version
#for i,vt in enumerate([np.random.normal(0,1, (4)), np.random.normal(0,1, (4)), np.random.normal(0,1, (4)), np.random.normal(0,1, (4))]):
vt = [.1,.1,.1,.1,]
results = {}
noise = 0.1
for lr_v in [0.01]:
    results[lr_v]={}
    for lr_wc in [0.001]: 
        results[lr_v][lr_wc] = []
        for s in np.arange(1):
            VT_i= np.array(vt)
            VS_i =control_VS(VT_i, np.pi/4)
            WT_i = np.random.normal(0, 0.001, (num_task,input_dim))*noise
            WS_i = WT_i.copy() + np.random.normal(0, 0.001, (num_task,input_dim))*noise
            ode_solver_nid = solver.CurriculumCompositionalTaskSimulator(input_dim = input_dim, seq_len = seq_len,
                                                                         num_task= num_task, identical = False,
                                                                         VS = VS_i, VT= VT_i, WS=WS_i, WT = WT_i)
            ode_solver_nid.train(lr = {'lr_w':1., 'lr_wc':lr_wc, 'lr_vc': lr_v},num_iter= nums_iter, update_frequency = update_frequency)
            results[lr_v][lr_wc].append(ode_solver_nid)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 18
#      14 WS_i = WT_i.copy() + np.random.normal(0, 0.001, (num_task,input_dim))*noise
#      15 ode_solver_nid = solver.CurriculumCompositionalTaskSimulator(input_dim = input_dim, seq_len = seq_len,
#      16                                                              num_task= num_task, identical = False,
#      17                                                              VS = VS_i, VT= VT_i, WS=WS_i, WT = WT_i)
# ---> 18 ode_solver_nid.train(lr = {'lr_w':1., 'lr_wc':lr_wc, 'lr_vc': lr_v},num_iter= nums_iter, update_frequency = update_frequency)
#      19 results[lr_v][lr_wc].append(ode_solver_nid)
#
# File ~/rotation_saxe/composite_learning/solver/simple_hrl_solver.py:363, in CurriculumCompositionalTaskSimulator.train(self, num_iter, update_frequency, lr)
#     360         self.update_history(history_index=i // update_frequency)
#     362 for i in range(num_iter[1]):
# --> 363     self.step()
#     364     if i % update_frequency == 0:
#     365         self.update_history(history_index=(num_iter[0] + i) //
#     366                             update_frequency)
#
# File ~/rotation_saxe/composite_learning/solver/simple_hrl_solver.py:207, in CompositionalTaskSimulator.step(self)
#     205     x = np.repeat(x, self.num_task, axis=0)
#     206 else:
# --> 207     x = np.random.normal(loc=0.0,
#     208                          scale=1.0,
#     209                          size=(self.num_task, self.input_dim,
#     210                                self.seq_len))
#     212 (y, y_sign, y_hat,
#     213  y_hat_sign), (y_tilde, y_tilde_hat, y_tilde_sign,
#     214                y_tilde_hat_sign) = self.inference(x)  #num_task*n_seq
#     216 if (y_tilde_sign == y_tilde_hat_sign).all():
#
# KeyboardInterrupt:

# %%
#plt.plot(ode_solver_nid.history['phase2']['VSVT'])
fig = plt.figure()
#for i in range(4):
    #plt.plot(ode_solver_nid.history['phase2']['R'][:,i,i]/np.sqrt(ode_solver_nid.history['phase2']['Q'][:,i,i])/np.sqrt(ode_solver_nid.S[i,i]))
plt.plot(ode_solver_nid.history['P'])    
fig = plt.figure()
plt.plot(ode_solver_nid.history['P_tilde'])

fig = plt.figure()
plt.plot(ode_solver_nid.history['VS'])

# %%
ode_solver_nid.VS
# Out:
# array([ 0.98953701,  0.10467909,  0.08993327, -0.04208089])

# %%
#plt.plot(ode_solver_nid.history['phase2']['VSVT'])
fig = plt.figure()
#for i in range(4):
    #plt.plot(ode_solver_nid.history['phase2']['R'][:,i,i]/np.sqrt(ode_solver_nid.history['phase2']['Q'][:,i,i])/np.sqrt(ode_solver_nid.S[i,i]))
plt.plot(ode_solver_nid.history['P'])    
fig = plt.figure()
plt.plot(ode_solver_nid.history['P_tilde'])

fig = plt.figure()
plt.plot(ode_solver_nid.history['VSVT'] )
# Out:
# [<matplotlib.lines.Line2D at 0x7f0162050ee0>,
#  <matplotlib.lines.Line2D at 0x7f01620517b0>,
#  <matplotlib.lines.Line2D at 0x7f0162051c90>,
#  <matplotlib.lines.Line2D at 0x7f0162051cc0>]

# %%
ode_solver_nid.history.keys()
# Out:
# dict_keys(['Q', 'R', 'P', 'VS', 'P_tilde'])

# %%
np.dot([1,1,0,0],[1,0,0,0])/np.linalg.norm([1,1,0,0]/np.linalg.norm([1,0,0,0]))
# Out:
# 0.7071067811865475

# %%
ode_solver_nid.VS
# Out:
# array([ 6.38287719, 89.95376501, -0.19975481, 62.18097277])

# %%
results = jl.load('curriculum_stability_1111_vsmallv.jl')

# %%
plt.plot(results[0.1][0.01][0].history['phase2']['P_tilde'])

# %%
plt.plot(results[0.1][0.01][0].history['phase2']['VS'])
# Out:
# [<matplotlib.lines.Line2D at 0x7fbee56701c0>,
#  <matplotlib.lines.Line2D at 0x7fbee56706d0>,
#  <matplotlib.lines.Line2D at 0x7fbee5670e20>,
#  <matplotlib.lines.Line2D at 0x7fbedf4209a0>]

# %%
lr_w= 1.
fig, axs=plt.subplots(nrows = 5,ncols=2, figsize= (12,18))
for j, lr_v in enumerate([0., 0.001, 0.01, 0.1,1]): 
    axs[j][0].plot(np.array([r.history['phase2']['P_tilde'] for r in results[lr_v][lr_w]])[0].T)
    axs[j][1].plot(results[lr_v][lr_w][0].history['phase2']['P'])
    axs[j][0].set_title(f'Compositional performance - lr_w2: {lr_w}, lr_v:{lr_v}')
    axs[j][1].set_title(f'Indiv. task performance - lr_w2: {lr_w}, lr_v:{lr_v}')

# %%
def gather_results(rootdir, identical):
    args = json.load(open(os.path.join(rootdir, 'args.json'), 'r'))
    ps = []
    pts= []
    if identical:
        identical_flag = 'id'
    else:
        identical_flag = 'nid'
    for path in glob.glob( rootdir+'/ode*'):
        ode=jl.load(path)
        p=ode[identical_flag]['phase2']['P']
        p_tilde=ode[identical_flag]['phase2']['P_tilde']
        vs=ode[identical_flag]['phase2']['VS'][0]
        #vt=ode[identical_flag]['VT']
        ps.append(p)
        pts.append(p_tilde)
        
    return np.array(ps), np.array(pts), args

# %%
jl

# %%
import glob
import joblib as jl
rootdirs=glob.glob('hrl_ode_logs/230823_VTVS_noise/*/')
lr_v = 1
fig, axs = plt.subplots(2,2, figsize=(12,9))
for i,lr_w in enumerate([1, 0.1, 0.01, 0.001]):
    res = {}
    for _, noise in enumerate([0.001,0.1, 1, 10]):
        for rootdir in rootdirs:
            ps, pts, args=gather_results(rootdir, identical = True)
            if args['lr_ws'] ==[0, lr_w] and args['lr_v'] ==lr_v and args['noise_scale']==noise:
                print(rootdir)
                res[noise]= pts[:,-1]

    ax = axs[i//2][i%2]
    sns.stripplot(res, ax = axs[i//2][i%2], color = 'k', alpha = 0.5)
    ax.set_title(f'lr_w:{lr_w}, lr_v:{lr_v}')
    ax.set_xlabel('Added noise to VS')
    ax.set_ylabel('Convergence score')
    ax.set_ylim([0,1])
# Out:
# hrl_ode_logs/230823_VTVS_noise/20230823195224.303622/
# hrl_ode_logs/230823_VTVS_noise/20230823195224.303695/
# hrl_ode_logs/230823_VTVS_noise/20230823195224.303676/
# hrl_ode_logs/230823_VTVS_noise/20230823195224.303833/
# /nfs/nhome/live/jlee/.conda/envs/composite_learning/lib/python3.10/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:k'` for same effect.
#   warnings.warn(msg, FutureWarning)
# hrl_ode_logs/230823_VTVS_noise/20230823195231.658186/
# hrl_ode_logs/230823_VTVS_noise/20230823195231.658351/
# hrl_ode_logs/230823_VTVS_noise/20230823195231.658131/
# hrl_ode_logs/230823_VTVS_noise/20230823195231.658452/
# /nfs/nhome/live/jlee/.conda/envs/composite_learning/lib/python3.10/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:k'` for same effect.
#   warnings.warn(msg, FutureWarning)
# hrl_ode_logs/230823_VTVS_noise/20230823195231.660193/
# hrl_ode_logs/230823_VTVS_noise/20230823195231.660173/
# hrl_ode_logs/230823_VTVS_noise/20230823195231.660146/
# hrl_ode_logs/230823_VTVS_noise/20230823195231.660841/
# /nfs/nhome/live/jlee/.conda/envs/composite_learning/lib/python3.10/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:k'` for same effect.
#   warnings.warn(msg, FutureWarning)
# hrl_ode_logs/230823_VTVS_noise/20230823195215.617745/
# hrl_ode_logs/230823_VTVS_noise/20230823195224.055229/
# /nfs/nhome/live/jlee/.conda/envs/composite_learning/lib/python3.10/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:k'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
pt=jl.load('hrl_ode_logs/230823_VTVS_noise/20230823195231.658186/ode_1.jl')['id']['phase2']['P_tilde']
p=jl.load('hrl_ode_logs/230823_VTVS_noise/20230823195231.658186/ode_1.jl')['id']['phase2']['P']

# %%
plt.plot(pt.T)

# %%
plt.plot(p.T[3])
